# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas_datareader as pdr

# %%
# 맥 폰트 깨짐 이슈 해결
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

# %%
scientists=pd.read_csv("da_data/scientists.csv")
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
ages = scientists['Age']
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
print(ages.max())
# Out:
# 90

# %%
print(ages.mean())
# Out:
# 59.125

# %%
print(ages[ages > ages.mean()])
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
print(ages + ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages * ages)
# Out:
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64

# %%
print(ages + 100)
# Out:
# 0    137
# 1    161
# 2    190
# 3    166
# 4    156
# 5    145
# 6    141
# 7    177
# Name: Age, dtype: int64

# %%
print(ages * 2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
pd.Series([1,100]) + ages
# Out:
# 0     38.0
# 1    161.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# dtype: float64

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
print(scientists[scientists['Age'] > scientists['Age'].mean()])
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
print(scientists * 2)
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %%
scientists['Born']
# Out:
# 0    1920-07-25
# 1    1876-06-13
# 2    1820-05-12
# 3    1867-11-07
# 4    1907-05-27
# 5    1813-03-15
# 6    1912-06-23
# 7    1777-04-30
# Name: Born, dtype: object

# %%
pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
born_datetime = pd.to_datetime(scientists['Born'], format='%Y-%m-%d') 
print(born_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
died_datetime = pd.to_datetime(scientists['Died'], format='%Y-%m-%d')
print(died_datetime)
# Out:
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[ns]

# %%
scientists['born_dt'], scientists['died_dt'] = (born_datetime, died_datetime)
print(scientists.head())
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16
# 2 1910-08-13
# 3 1934-07-04
# 4 1964-04-14

# %%
scientists.shape
# Out:
# (8, 7)

# %%
# 생존 기간 (일) 출력
# scientists.info()

scientists['died_dt'] - scientists['born_dt']
# Out:
# 0   13779 days
# 1   22404 days
# 2   32964 days
# 3   24345 days
# 4   20777 days
# 5   16529 days
# 6   15324 days
# 7   28422 days
# dtype: timedelta64[ns]

# %%
scientists['age_days_dt'] =scientists['died_dt'] - scientists['born_dt']
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# ...

# %%
anscombe = sns.load_dataset("anscombe") 
print(anscombe)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II'] 
dataset_3 = anscombe[anscombe['dataset'] == 'III'] 
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
dataset_1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
dataset_2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
dataset_3.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
dataset_4.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
plt.plot(dataset_1['x'],dataset_1['y'])

# %%
plt.plot(dataset_1['x'],dataset_1['y'],'o')

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o') 
axes2.plot(dataset_2['x'], dataset_2['y'], 'o') 
axes3.plot(dataset_3['x'], dataset_3['y'], 'o') 
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %%
tips = sns.load_dataset("tips") 
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig = plt.figure() # 도화지라고 생각하면 편함
axes1 = fig.add_subplot(1, 1, 1) # add_subplot : 도화지를 여러 영역으로 나눔

# %%
axes1.hist(tips['total_bill'], bins=10) 
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency') 
axes1.set_ylabel('Total Bill')
fig

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1, 1, 1) 
axes1.scatter(tips['total_bill'], tips['tip']) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(2, 2, 4) 
axes1.scatter(tips['total_bill'], tips['tip']) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1, 1, 1) 

axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])


axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/2694438044.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes1.boxplot(
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
df1 = pd.read_csv("da_data/concat_1.csv")
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df2 = pd.read_csv("da_data/concat_2.csv")
df2
# Out:
#     A   B   C   D
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
df3 = pd.read_csv("da_data/concat_3.csv")
df3
# Out:
#      A    B    C    D
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
row_concat = pd.concat([df1, df2, df3]) 
print(row_concat)
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
print(row_concat.iloc[3, ])
print(row_concat.loc[3, ])
# Out:
# A    a3
# B    b3
# C    c3
# D    d3
# Name: 3, dtype: object
#      A    B    C    D
# 3   a3   b3   c3   d3
# 3   a7   b7   c7   d7
# 3  a11  b11  c11  d11

# %%
gapminder=pd.read_csv("da_data/gapminder.tsv", sep='\t')
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
# 전세계인에 대해 연도별 기대수명의 평균랎을 출력
life_exp = gapminder.groupby(['year'])['lifeExp'].mean()
print(life_exp)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
life_exp.index
life_exp.index >2000
life_exp[life_exp.index >2000]
# Out:
# year
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
ebola = pd.read_csv('da_data/country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola.count()
# Out:
# Date                   122
# Day                    122
# Cases_Guinea            93
# Cases_Liberia           83
# Cases_SierraLeone       87
# Cases_Nigeria           38
# Cases_Senegal           25
# Cases_UnitedStates      18
# Cases_Spain             16
# Cases_Mali              12
# Deaths_Guinea           92
# Deaths_Liberia          81
# Deaths_SierraLeone      87
# Deaths_Nigeria          38
# Deaths_Senegal          22
# Deaths_UnitedStates     18
# Deaths_Spain            16
# Deaths_Mali             12
# dtype: int64

# %%
ebola.shape
# Out:
# (122, 18)

# %%
num_rows = ebola.shape[0]
num_missing = num_rows - ebola.count()
num_missing
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
ebola.Cases_Guinea.value_counts()
# Out:
# Cases_Guinea
# 86.0      3
# 495.0     2
# 112.0     2
# 390.0     2
# 408.0     1
#          ..
# 1199.0    1
# 1298.0    1
# 1350.0    1
# 1472.0    1
# 49.0      1
# Name: count, Length: 88, dtype: int64

# %%
ebola.Cases_Guinea.value_counts(dropna=False)
# Out:
# Cases_Guinea
# NaN       29
# 86.0       3
# 495.0      2
# 112.0      2
# 390.0      2
#           ..
# 1199.0     1
# 1298.0     1
# 1350.0     1
# 1472.0     1
# 49.0       1
# Name: count, Length: 89, dtype: int64

# %%
ebola
ebola.fillna(0)
ebola.fillna(method='ffill')
ebola.fillna(method='bfill')
ebola.interpolate()
# Out:
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/684486207.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ebola.fillna(method='ffill')
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/684486207.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ebola.fillna(method='bfill')
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/684486207.py:5: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ebola.interpolate()
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# ...

# %%
ebola.dropna()
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 19  11/18/2014  241        2047.0         7082.0             6190.0
#
#     Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 19           20.0            1.0                 4.0          1.0         6.0
#
#     Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 19         1214.0          2963.0              1267.0             8.0
#
#     Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 19             0.0                  1.0           0.0          6.0

# %%
ebola['Cases_Guinea']
ebola['Cases_Liberia']
ebola['Cases_SierraLeone']
# Out:
# 0      10030.0
# 1       9780.0
# 2       9722.0
# 3          NaN
# 4       9633.0
#         ...
# 117        6.0
# 118        NaN
# 119        NaN
# 120        NaN
# 121        NaN
# Name: Cases_SierraLeone, Length: 122, dtype: float64

# %%
ebola['Cases_multiple'] = ebola['Cases_Guinea'] + ebola['Cases_Liberia'] + ebola['Cases_SierraLeone']
ebola['Cases_multiple']
# Out:
# 0          NaN
# 1          NaN
# 2      20657.0
# 3          NaN
# 4      20478.0
#         ...
# 117      117.0
# 118        NaN
# 119        NaN
# 120        NaN
# 121        NaN
# Name: Cases_multiple, Length: 122, dtype: float64

# %%
ebola_subset = ebola.loc[:, ['Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone', 'Cases_multiple']]

# %%
ebola_subset
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_multiple
# 0          2776.0            NaN            10030.0             NaN
# 1          2775.0            NaN             9780.0             NaN
# 2          2769.0         8166.0             9722.0         20657.0
# 3             NaN         8157.0                NaN             NaN
# 4          2730.0         8115.0             9633.0         20478.0
# ..            ...            ...                ...             ...
# 117         103.0            8.0                6.0           117.0
# 118          86.0            NaN                NaN             NaN
# 119          86.0            NaN                NaN             NaN
# 120          86.0            NaN                NaN             NaN
# 121          49.0            NaN                NaN             NaN
#
# [122 rows x 4 columns]

# %%
pew=pd.read_csv('da_data/pew.csv')
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pew.shape
# Out:
# (18, 11)

# %%
# 데이터 구조 변경 1
pd.melt(pew)
# Out:
#                variable               value
# 0              religion            Agnostic
# 1              religion             Atheist
# 2              religion            Buddhist
# 3              religion            Catholic
# 4              religion  Don’t know/refused
# ..                  ...                 ...
# 193  Don't know/refused                  73
# 194  Don't know/refused                  18
# 195  Don't know/refused                  71
# 196  Don't know/refused                   8
# 197  Don't know/refused                 597
#
# [198 rows x 2 columns]

# %%
# 데이터 구조 변경 2
pd.melt(pew,id_vars='religion')
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
# 데이터 구조 변경 3
pd.melt(pew, id_vars='religion', var_name='income', value_name='count')
# religoin 열을 고정하고 나머지 열들은 행으로 변환하기
# Out:
#                   religion              income  count
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
billboard=pd.read_csv('da_data/billboard.csv')
billboard

	year	artist	track	time	date.entered	wk1	wk2	wk3	wk4	wk5	...	wk67	wk68	wk69	wk70	wk71	wk72	wk73	wk74	wk75	wk76
0	2000	2 Pac	Baby Don't Cry (Keep...	4:22	2000-02-26	87	82.0	72.0	77.0	87.0	...	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN
1	2000	2Ge+her	The Hardest Part Of ...	3:15	2000-09-02	91	87.0	92.0	NaN	NaN	...	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN
2	2000	3 Doors Down	Kryptonite	3:53	2000-04-08	81	70.0	68.0	67.0	66.0	...	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN
3	2000	3 Doors Down	Loser	4:24	2000-10-21	76	76.0	72.0	69.0	67.0	...	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN
4	2000	504 Boyz	Wobble Wobble	3:35	2000-04-15	57	34.0	25.0	17.0	17.0	...	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN
# Out:
#      year            artist                    track  time date.entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
pd.melt(billboard, id_vars=['year', 'artist', 'track', 'time',
'date.entered'], var_name='week', value_name='rating')
# Out:
#        year            artist                    track  time date.entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  rating
# 0       wk1    87.0
# 1       wk1    91.0
# ...

# %%
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.columns
# Out:
# Index(['Date', 'Day', 'Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain',
#        'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone',
#        'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates',
#        'Deaths_Spain', 'Deaths_Mali', 'Cases_multiple'],
#       dtype='object')

# %%
ebola.iloc[:5,[0,1,2,3,10,11]]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Deaths_Guinea  Deaths_Liberia
# 0    1/5/2015  289        2776.0            NaN         1786.0             NaN
# 1    1/4/2015  288        2775.0            NaN         1781.0             NaN
# 2    1/3/2015  287        2769.0         8166.0         1767.0          3496.0
# 3    1/2/2015  286           NaN         8157.0            NaN          3496.0
# 4  12/31/2014  284        2730.0         8115.0         1739.0          3471.0

# %%
# pd.melt(ebola, id_vars=['Date','Day'])
pd.melt(ebola, id_vars=['Date','Day'])
# Out:
#             Date  Day        variable   value
# 0       1/5/2015  289    Cases_Guinea  2776.0
# 1       1/4/2015  288    Cases_Guinea  2775.0
# 2       1/3/2015  287    Cases_Guinea  2769.0
# 3       1/2/2015  286    Cases_Guinea     NaN
# 4     12/31/2014  284    Cases_Guinea  2730.0
# ...          ...  ...             ...     ...
# 2069   3/27/2014    5  Cases_multiple   117.0
# 2070   3/26/2014    4  Cases_multiple     NaN
# 2071   3/25/2014    3  Cases_multiple     NaN
# 2072   3/24/2014    2  Cases_multiple     NaN
# 2073   3/22/2014    0  Cases_multiple     NaN
#
# [2074 rows x 4 columns]

# %%
ebola_long = pd.melt(ebola, id_vars=['Date', 'Day'])
print(ebola_long.head())
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
# Series라서 str. 붙혀야한다.
ebola_long.variable.str.split('_')
# Out:
# 0         [Cases, Guinea]
# 1         [Cases, Guinea]
# 2         [Cases, Guinea]
# 3         [Cases, Guinea]
# 4         [Cases, Guinea]
#               ...
# 2069    [Cases, multiple]
# 2070    [Cases, multiple]
# 2071    [Cases, multiple]
# 2072    [Cases, multiple]
# 2073    [Cases, multiple]
# Name: variable, Length: 2074, dtype: object

# %%
variable_split = ebola_long.variable.str.split('_')

# %%
variable_split.str[0]
variable_split.str[1]
# Out:
# 0         Guinea
# 1         Guinea
# 2         Guinea
# 3         Guinea
# 4         Guinea
#           ...
# 2069    multiple
# 2070    multiple
# 2071    multiple
# 2072    multiple
# 2073    multiple
# Name: variable, Length: 2074, dtype: object

# %%
variable_split.str.get(0)
# Out:
# 0       Cases
# 1       Cases
# 2       Cases
# 3       Cases
# 4       Cases
#         ...
# 2069    Cases
# 2070    Cases
# 2071    Cases
# 2072    Cases
# 2073    Cases
# Name: variable, Length: 2074, dtype: object

# %%
ebola_long
# Out:
#             Date  Day        variable   value
# 0       1/5/2015  289    Cases_Guinea  2776.0
# 1       1/4/2015  288    Cases_Guinea  2775.0
# 2       1/3/2015  287    Cases_Guinea  2769.0
# 3       1/2/2015  286    Cases_Guinea     NaN
# 4     12/31/2014  284    Cases_Guinea  2730.0
# ...          ...  ...             ...     ...
# 2069   3/27/2014    5  Cases_multiple   117.0
# 2070   3/26/2014    4  Cases_multiple     NaN
# 2071   3/25/2014    3  Cases_multiple     NaN
# 2072   3/24/2014    2  Cases_multiple     NaN
# 2073   3/22/2014    0  Cases_multiple     NaN
#
# [2074 rows x 4 columns]

# %%
ebola_long['status'] = variable_split.str.get(0)
ebola_long
# Out:
#             Date  Day        variable   value status   country
# 0       1/5/2015  289    Cases_Guinea  2776.0  Cases    Guinea
# 1       1/4/2015  288    Cases_Guinea  2775.0  Cases    Guinea
# 2       1/3/2015  287    Cases_Guinea  2769.0  Cases    Guinea
# 3       1/2/2015  286    Cases_Guinea     NaN  Cases    Guinea
# 4     12/31/2014  284    Cases_Guinea  2730.0  Cases    Guinea
# ...          ...  ...             ...     ...    ...       ...
# 2069   3/27/2014    5  Cases_multiple   117.0  Cases  multiple
# 2070   3/26/2014    4  Cases_multiple     NaN  Cases  multiple
# 2071   3/25/2014    3  Cases_multiple     NaN  Cases  multiple
# 2072   3/24/2014    2  Cases_multiple     NaN  Cases  multiple
# 2073   3/22/2014    0  Cases_multiple     NaN  Cases  multiple
#
# [2074 rows x 6 columns]

# %%
ebola_long['country']=variable_split.str.get(1)
ebola_long
# Out:
#             Date  Day        variable   value status   country
# 0       1/5/2015  289    Cases_Guinea  2776.0  Cases    Guinea
# 1       1/4/2015  288    Cases_Guinea  2775.0  Cases    Guinea
# 2       1/3/2015  287    Cases_Guinea  2769.0  Cases    Guinea
# 3       1/2/2015  286    Cases_Guinea     NaN  Cases    Guinea
# 4     12/31/2014  284    Cases_Guinea  2730.0  Cases    Guinea
# ...          ...  ...             ...     ...    ...       ...
# 2069   3/27/2014    5  Cases_multiple   117.0  Cases  multiple
# 2070   3/26/2014    4  Cases_multiple     NaN  Cases  multiple
# 2071   3/25/2014    3  Cases_multiple     NaN  Cases  multiple
# 2072   3/24/2014    2  Cases_multiple     NaN  Cases  multiple
# 2073   3/22/2014    0  Cases_multiple     NaN  Cases  multiple
#
# [2074 rows x 6 columns]

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
# astype : 타입 변환
tips['sex_str'] = tips['sex'].astype(str)
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_str
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Female
# 1         10.34  1.66    Male     No   Sun  Dinner     3    Male
# 2         21.01  3.50    Male     No   Sun  Dinner     3    Male
# 3         23.68  3.31    Male     No   Sun  Dinner     2    Male
# 4         24.59  3.61  Female     No   Sun  Dinner     4  Female
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    Male
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  Female
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    Male
# 242       17.82  1.75    Male     No   Sat  Dinner     2    Male
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Female
#
# [244 rows x 8 columns]

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object

# %%
tips['total_bill'] = tips['total_bill'].astype(str) # astype(float)

# %%
tips
# Out:
#     total_bill   tip     sex smoker   day    time  size sex_str
# 0        16.99  1.01  Female     No   Sun  Dinner     2  Female
# 1        10.34  1.66    Male     No   Sun  Dinner     3    Male
# 2        21.01  3.50    Male     No   Sun  Dinner     3    Male
# 3        23.68  3.31    Male     No   Sun  Dinner     2    Male
# 4        24.59  3.61  Female     No   Sun  Dinner     4  Female
# ..         ...   ...     ...    ...   ...     ...   ...     ...
# 239      29.03  5.92    Male     No   Sat  Dinner     3    Male
# 240      27.18  2.00  Female    Yes   Sat  Dinner     2  Female
# 241      22.67  2.00    Male    Yes   Sat  Dinner     2    Male
# 242      17.82  1.75    Male     No   Sat  Dinner     2    Male
# 243      18.78  3.00  Female     No  Thur  Dinner     2  Female
#
# [244 rows x 8 columns]

# %%
tips['sex_cate'] = tips['sex'].astype('category')

# %%
tips.dtypes
# Out:
# total_bill      object
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# sex_cate      category
# dtype: object

# %%
d1 = '40°' 
m1 = "46'" 
s1 = '52.837"' 
u1 = 'N'

d2 = '73°' 
m2 = "58'" 
s2 = '26.302"' 
u2 = 'W'

# %%
# join 함수 : 문자열 합치기
coords = ' '.join([d1, m1, s1, u1, d2, m2, s2, u2])
print(coords)
# Out:
# 40° 46' 52.837" N 73° 58' 26.302" W

# %%
multi_str = """Guard: What? Ridden on a horse?
King Arthur: Yes!
Guard: You're using coconuts!
King Arthur: What?
Guard: You've got ... coconut[s] and you're bangin' 'em together. 
""" 
print(multi_str)
# Out:
# Guard: What? Ridden on a horse?
# King Arthur: Yes!
# Guard: You're using coconuts!
# King Arthur: What?
# Guard: You've got ... coconut[s] and you're bangin' 'em together.

# %%
# splitlines : 줄단위로 나누기
multi_str_split = multi_str.splitlines() 
print(multi_str_split)
# Out:
# ['Guard: What? Ridden on a horse?', 'King Arthur: Yes!', "Guard: You're using coconuts!", 'King Arthur: What?', "Guard: You've got ... coconut[s] and you're bangin' 'em together. "]

# %%
multi_str
# Out:
# "Guard: What? Ridden on a horse?\nKing Arthur: Yes!\nGuard: You're using coconuts!\nKing Arthur: What?\nGuard: You've got ... coconut[s] and you're bangin' 'em together. \n"

# %%
multi_str.replace('Guard: ', "")
# Out:
# "What? Ridden on a horse?\nKing Arthur: Yes!\nYou're using coconuts!\nKing Arthur: What?\nYou've got ... coconut[s] and you're bangin' 'em together. \n"

# %%
df = pd.read_csv('da_data/gapminder.tsv', sep='\t')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
years = df.year.unique() 
print(years)
# 1952년 자료만 추출하여 y1952 변에 저장
# Out:
# [1952 1957 1962 1967 1972 1977 1982 1987 1992 1997 2002 2007]

# %%
# 1952년 자료만 추출하여 y1952 변에 저장
# y1952=df[df['year']==1952]
y1952=df.loc[df.year==1952, :]
y1952

# %%
tips['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
tips.groupby("size").filter(lambda x: x['size'].count()>30)
# Out:
#     total_bill   tip     sex smoker   day    time  size sex_str sex_cate
# 0        16.99  1.01  Female     No   Sun  Dinner     2  Female   Female
# 1        10.34  1.66    Male     No   Sun  Dinner     3    Male     Male
# 2        21.01  3.50    Male     No   Sun  Dinner     3    Male     Male
# 3        23.68  3.31    Male     No   Sun  Dinner     2    Male     Male
# 4        24.59  3.61  Female     No   Sun  Dinner     4  Female   Female
# ..         ...   ...     ...    ...   ...     ...   ...     ...      ...
# 239      29.03  5.92    Male     No   Sat  Dinner     3    Male     Male
# 240      27.18  2.00  Female    Yes   Sat  Dinner     2  Female   Female
# 241      22.67  2.00    Male    Yes   Sat  Dinner     2    Male     Male
# 242      17.82  1.75    Male     No   Sat  Dinner     2    Male     Male
# 243      18.78  3.00  Female     No  Thur  Dinner     2  Female   Female
#
# [231 rows x 9 columns]

# %%
tips_10 = tips.sample(10,random_state=3)
tips_10
# Out:
#     total_bill   tip     sex smoker   day    time  size sex_str sex_cate
# 14       14.83  3.02  Female     No   Sun  Dinner     2  Female   Female
# 134      18.26  3.25  Female     No  Thur   Lunch     2  Female   Female
# 126       8.52  1.48    Male     No  Thur   Lunch     2    Male     Male
# 6         8.77  2.00    Male     No   Sun  Dinner     2    Male     Male
# 61       13.81  2.00    Male    Yes   Sat  Dinner     2    Male     Male
# 133      12.26  2.00  Female     No  Thur   Lunch     2  Female   Female
# 125       29.8  4.20  Female     No  Thur   Lunch     6  Female   Female
# 182      45.35  3.50    Male    Yes   Sun  Dinner     3    Male     Male
# 43        9.68  1.32    Male     No   Sun  Dinner     2    Male     Male
# 143      27.05  5.00  Female     No  Thur   Lunch     6  Female   Female

# %%
grouped = tips_10.groupby('sex')
grouped
# Out:
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/3496850849.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tips_10.groupby('sex')

# %%
# grouped.groups
grouped

# %%
grouped.mean(numeric_only=True)
# Out:
#           tip  size
# sex
# Male    2.060   2.2
# Female  3.494   3.6

# %%
date_str = ["2018, 1, 1", "2018, 1, 4", "2018, 1, 5", "2018, 1, 6"]
date_str

idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-04', '2018-01-05', '2018-01-06'], dtype='datetime64[ns]', freq=None)

# %%
date_str
# Out:
# ['2018, 1, 1', '2018, 1, 4', '2018, 1, 5', '2018, 1, 6']

# %%
np.random.seed(0)
s = pd.Series(np.random.randn(4), index=idx)
s
# Out:
# 2018-01-01    1.764052
# 2018-01-04    0.400157
# 2018-01-05    0.978738
# 2018-01-06    2.240893
# dtype: float64

# %%
pd.date_range("2024-02-28","2024-06-03")
# Out:
# DatetimeIndex(['2024-02-28', '2024-02-29', '2024-03-01', '2024-03-02',
#                '2024-03-03', '2024-03-04', '2024-03-05', '2024-03-06',
#                '2024-03-07', '2024-03-08', '2024-03-09', '2024-03-10',
#                '2024-03-11', '2024-03-12', '2024-03-13', '2024-03-14',
#                '2024-03-15', '2024-03-16', '2024-03-17', '2024-03-18',
#                '2024-03-19', '2024-03-20', '2024-03-21', '2024-03-22',
#                '2024-03-23', '2024-03-24', '2024-03-25', '2024-03-26',
#                '2024-03-27', '2024-03-28', '2024-03-29', '2024-03-30',
#                '2024-03-31', '2024-04-01', '2024-04-02', '2024-04-03',
#                '2024-04-04', '2024-04-05', '2024-04-06', '2024-04-07',
#                '2024-04-08', '2024-04-09', '2024-04-10', '2024-04-11',
#                '2024-04-12', '2024-04-13', '2024-04-14', '2024-04-15',
#                '2024-04-16', '2024-04-17', '2024-04-18', '2024-04-19',
# ...

# %%
pd.date_range(start="2024-4-1", periods=50, freq='H')
# Out:
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/3711457905.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start="2024-4-1", periods=50, freq='H')
# DatetimeIndex(['2024-04-01 00:00:00', '2024-04-01 01:00:00',
#                '2024-04-01 02:00:00', '2024-04-01 03:00:00',
#                '2024-04-01 04:00:00', '2024-04-01 05:00:00',
#                '2024-04-01 06:00:00', '2024-04-01 07:00:00',
#                '2024-04-01 08:00:00', '2024-04-01 09:00:00',
#                '2024-04-01 10:00:00', '2024-04-01 11:00:00',
#                '2024-04-01 12:00:00', '2024-04-01 13:00:00',
#                '2024-04-01 14:00:00', '2024-04-01 15:00:00',
#                '2024-04-01 16:00:00', '2024-04-01 17:00:00',
#                '2024-04-01 18:00:00', '2024-04-01 19:00:00',
#                '2024-04-01 20:00:00', '2024-04-01 21:00:00',
#                '2024-04-01 22:00:00', '2024-04-01 23:00:00',
# ...

# %%
pd.date_range("2024-6-3", "2024-12-31", freq="W") # 일요일 기준으로 주간이 나옴
# Out:
# DatetimeIndex(['2024-06-09', '2024-06-16', '2024-06-23', '2024-06-30',
#                '2024-07-07', '2024-07-14', '2024-07-21', '2024-07-28',
#                '2024-08-04', '2024-08-11', '2024-08-18', '2024-08-25',
#                '2024-09-01', '2024-09-08', '2024-09-15', '2024-09-22',
#                '2024-09-29', '2024-10-06', '2024-10-13', '2024-10-20',
#                '2024-10-27', '2024-11-03', '2024-11-10', '2024-11-17',
#                '2024-11-24', '2024-12-01', '2024-12-08', '2024-12-15',
#                '2024-12-22', '2024-12-29'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
np.random.seed(0)
ts = pd.Series(np.random.randn(4), index=pd.date_range(
    "2024-8-1", periods=4, freq="M")) # freq="M" 달의 마지막 날
ts
# Out:
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/2386554490.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   ts = pd.Series(np.random.randn(4), index=pd.date_range(
# 2024-08-31    1.764052
# 2024-09-30    0.400157
# 2024-10-31    0.978738
# 2024-11-30    2.240893
# Freq: ME, dtype: float64

# %%
ts.shift(1)
# Out:
# 2024-08-31         NaN
# 2024-09-30    1.764052
# 2024-10-31    0.400157
# 2024-11-30    0.978738
# Freq: ME, dtype: float64

# %%
ts.shift(-1)
# Out:
# 2024-08-31    0.400157
# 2024-09-30    0.978738
# 2024-10-31    2.240893
# 2024-11-30         NaN
# Freq: ME, dtype: float64

# %%
ts = pd.Series(np.random.randn(100), index=pd.date_range(
    "2024-1-1", periods=100, freq="D"))

ts
# Out:
# 2024-01-01    1.867558
# 2024-01-02   -0.977278
# 2024-01-03    0.950088
# 2024-01-04   -0.151357
# 2024-01-05   -0.103219
#                 ...
# 2024-04-05    0.401989
# 2024-04-06    1.883151
# 2024-04-07   -1.347759
# 2024-04-08   -1.270485
# 2024-04-09    0.969397
# Freq: D, Length: 100, dtype: float64

# %%
ts.resample('W').mean()
# Out:
# 2024-01-07    0.305776
# 2024-01-14    0.629064
# 2024-01-21   -0.006910
# 2024-01-28    0.277065
# 2024-02-04   -0.144972
# 2024-02-11   -0.496299
# 2024-02-18   -0.474473
# 2024-02-25   -0.201222
# 2024-03-03   -0.775142
# 2024-03-10    0.052868
# 2024-03-17   -0.450379
# 2024-03-24    0.601892
# 2024-03-31    0.334893
# 2024-04-07    0.509605
# 2024-04-14   -0.150544
# Freq: W-SUN, dtype: float64

# %%
s = pd.Series(pd.date_range("2020-12-25", periods=100, freq="D"))
s
# Out:
# 0    2020-12-25
# 1    2020-12-26
# 2    2020-12-27
# 3    2020-12-28
# 4    2020-12-29
#         ...
# 95   2021-03-30
# 96   2021-03-31
# 97   2021-04-01
# 98   2021-04-02
# 99   2021-04-03
# Length: 100, dtype: datetime64[ns]

# %%
s.dt.year
s.dt.weekday
s.dt.strftime("%Y년 %m월 %d일")
# Out:
# 0     2020년 12월 25일
# 1     2020년 12월 26일
# 2     2020년 12월 27일
# 3     2020년 12월 28일
# 4     2020년 12월 29일
#           ...
# 95    2021년 03월 30일
# 96    2021년 03월 31일
# 97    2021년 04월 01일
# 98    2021년 04월 02일
# 99    2021년 04월 03일
# Length: 100, dtype: object

# %%
from datetime import datetime

# %%
datetime.now()
datetime.today()
# Out:
# datetime.datetime(2024, 6, 3, 14, 32, 14, 687165)

# %%
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola['date_dt'] = pd.to_datetime(ebola['Date'])
ebola['date_dt']
# Out:
# 0     2015-01-05
# 1     2015-01-04
# 2     2015-01-03
# 3     2015-01-02
# 4     2014-12-31
#          ...
# 117   2014-03-27
# 118   2014-03-26
# 119   2014-03-25
# 120   2014-03-24
# 121   2014-03-22
# Name: date_dt, Length: 122, dtype: datetime64[ns]

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
test_df1 = pd.DataFrame({'order_day':['01/01/15', '02/01/15', '03/01/15']})
test_df1
# Out:
#   order_day
# 0  01/01/15
# 1  02/01/15
# 2  03/01/15

# %%
pd.to_datetime(test_df1['order_day'], format='%m/%d/%y')
# Out:
# 0   2015-01-01
# 1   2015-02-01
# 2   2015-03-01
# Name: order_day, dtype: datetime64[ns]

# %%
pd.to_datetime(test_df1['order_day'], format='%d/%m/%y')
# Out:
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# Name: order_day, dtype: datetime64[ns]

# %%
pd.to_datetime(test_df1['order_day'], format='%y/%m/%d')
# Out:
# 0   2001-01-15
# 1   2002-01-15
# 2   2003-01-15
# Name: order_day, dtype: datetime64[ns]

# %%
test_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   order_day  3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
test_df2 = pd.DataFrame({'order_day':['01-01-15', '02-01-15', '03-01-15']})
test_df2
# 일 월 년 순으로 출력
# Out:
#   order_day
# 0  01-01-15
# 1  02-01-15
# 2  03-01-15

# %%
pd.to_datetime(test_df2['order_day'], format='%d-%m-%y')
# Out:
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# Name: order_day, dtype: datetime64[ns]

# %%
pd.read_csv('da_data/country_timeseries.csv')
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola_df = pd.read_csv('da_data/country_timeseries.csv',parse_dates=['Date'])
ebola_df
ebola_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola_df.Date
# Out:
# 0     2015-01-05
# 1     2015-01-04
# 2     2015-01-03
# 3     2015-01-02
# 4     2014-12-31
#          ...
# 117   2014-03-27
# 118   2014-03-26
# 119   2014-03-25
# 120   2014-03-24
# 121   2014-03-22
# Name: Date, Length: 122, dtype: datetime64[ns]

# %%
ebola_df.Date.dt.year
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2014
#        ...
# 117    2014
# 118    2014
# 119    2014
# 120    2014
# 121    2014
# Name: Date, Length: 122, dtype: int32

# %%
ebola_df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
# 에볼라 바이러스가 리베리아(cases_liberia)에서 발병한 바이러스가 누적 발병자 수의 최대값에 해당된느 날짜는?
ebola_df[ebola_df.Cases_Liberia == ebola_df['Cases_Liberia'].max()]['Date']
# Out:
# 2   2015-01-03
# Name: Date, dtype: datetime64[ns]

# %%
banks = pd.read_csv('da_data/banklist.csv',parse_dates = [5,6])
banks.info()
# Out:
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/1565650656.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks = pd.read_csv('da_data/banklist.csv',parse_dates = [5,6])
# /var/folders/bs/rn4q13z924s9_wzlq41h6grc0000gn/T/ipykernel_1564/1565650656.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks = pd.read_csv('da_data/banklist.csv',parse_dates = [5,6])
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    object
#  1   City                   555 non-null    object
# ...

# %%
banks['Closing Date'].dt.quarter
# Out:
# 0      4
# 1      4
# 2      2
# 3      2
# 4      2
#       ..
# 550    3
# 551    2
# 552    1
# 553    4
# 554    4
# Name: Closing Date, Length: 555, dtype: int32

# %%
banks['Closing Date'].dt.year
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 550    2001
# 551    2001
# 552    2001
# 553    2000
# 554    2000
# Name: Closing Date, Length: 555, dtype: int32

# %%
# banks Closing Date열을 참조하여 연도별로 문을 닫은 은행의 갯수를 출력
banks.groupby(banks['Closing Date'].dt.year)['Bank Name'].count()
# Out:
# Closing Date
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# Name: Bank Name, dtype: int64

# %%
import pandas_datareader as pdr

# %%
pdr.get_data_quandl("TSLA",api_key="fifzdx-upoyGn5S5J3CS")
TSLA.to_csv('TSLA.csv')
#   www.quandl.com 가입 -> api 키 발급
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[268], line 2
#       1 pdr.get_data_quandl("TSLA",api_key="fifzdx-upoyGn5S5J3CS")
# ----> 2 TSLA.to_csv('TSLA.csv')
#       3 #   www.quandl.com 가입 -> api 키 발급
#
# NameError: name 'TSLA' is not defined

# %%
pdr.get_data_quandl("TSLA",api_key="apizl")
TSLA.to_csv('TSLA.csv')

# %%
tsla_df = pd.read_csv("TSLA.csv")
tsla_df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2024-03-04  198.729996  199.750000  186.720001  188.139999  188.139999
# 1   2024-03-05  183.050003  184.589996  177.570007  180.740005  180.740005
# 2   2024-03-06  179.990005  181.580002  173.699997  176.539993  176.539993
# 3   2024-03-07  174.350006  180.039993  173.699997  178.649994  178.649994
# 4   2024-03-08  181.500000  182.729996  174.699997  175.339996  175.339996
# ..         ...         ...         ...         ...         ...         ...
# 58  2024-05-24  174.839996  180.080002  173.729996  179.240005  179.240005
# 59  2024-05-28  176.399994  178.250000  173.160004  176.750000  176.750000
# 60  2024-05-29  174.190002  178.149994  173.929993  176.190002  176.190002
# 61  2024-05-30  178.580002  182.669998  175.380005  178.789993  178.789993
# 62  2024-05-31  178.500000  180.320007  173.820007  178.080002  178.080002
#
#        Volume
# 0   134334900
# 1   119660800
# 2   107920900
# ...

# %%
tsla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       63 non-null     object
#  1   Open       63 non-null     float64
#  2   High       63 non-null     float64
#  3   Low        63 non-null     float64
#  4   Close      63 non-null     float64
#  5   Adj Close  63 non-null     float64
#  6   Volume     63 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.6+ KB

# %%
# Date 열에서 월을 추출
# 1
tsla_df['Date'] =pd.to_datetime(tsla_df['Date'])
tsla_df['Month'] = tsla_df['Date'].dt.month
tsla_df['Month']

# 2
pd.to_datetime(tsla_df['Date']).dt.month
# Out:
# 0     3
# 1     3
# 2     3
# 3     3
# 4     3
#      ..
# 58    5
# 59    5
# 60    5
# 61    5
# 62    5
# Name: Month, Length: 63, dtype: int32

# %%
# 2024년 4월에 해당되는 자료를 출력

# %%
# 2024년 4월에 해당하는 자료를 필터링합니다.
tsla_df[(tsla_df['Date'].dt.year == 2024) & (tsla_df['Date'].dt.month == 4)]
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 19 2024-04-01  176.169998  176.750000  170.210007  175.220001  175.220001
# 20 2024-04-02  164.750000  167.690002  163.429993  166.630005  166.630005
# 21 2024-04-03  164.020004  168.820007  163.279999  168.380005  168.380005
# 22 2024-04-04  170.070007  177.190002  168.009995  171.110001  171.110001
# 23 2024-04-05  169.080002  170.860001  160.509995  164.899994  164.899994
# 24 2024-04-08  169.339996  174.500000  167.789993  172.979996  172.979996
# 25 2024-04-09  172.910004  179.220001  171.919998  176.880005  176.880005
# 26 2024-04-10  173.039993  174.929993  170.009995  171.759995  171.759995
# 27 2024-04-11  172.550003  175.880005  168.509995  174.600006  174.600006
# 28 2024-04-12  172.339996  173.809998  170.360001  171.050003  171.050003
# 29 2024-04-15  170.240005  170.690002  161.380005  161.479996  161.479996
# 30 2024-04-16  156.740005  158.190002  153.750000  157.110001  157.110001
# ...

# %%
# 1. 테슬라
tsla_df = pd.read_csv("TSLA.csv")
# 1) High / Low /Close / Volume 열에 대해 최대/최소/평균/중위수 출력
# 1-1 High
high_tsla = tsla_df['High'].agg(['max','min','mean','median'])
# 1-2 Low
low_tsla = tsla_df['Low'].agg(['max','min','mean','median'])
# 1-3 Close
close_tsla = tsla_df['Close'].agg(['max','min','mean','median'])
# 1-4 Volume
valume_tsla = tsla_df['Volume'].agg(['max','min','mean','median'])

# 2) Open열과 Close 열 값의 차이가 가장 큰 날짜는 언제인가?
tsla_df['Open_Close_Diff'] = abs(tsla_df['Open'] - tsla_df['Close'])
max_diff_date = tsla_df.loc[tsla_df['Open_Close_Diff'].idxmax(), 'Date']
print("편차가 큰 날짜는:", max_diff_date)

# 3) Volume(거래량)이 가장 높았던 날에는 주가가 올랐을까 내렸을까?
max_date = tsla_df.loc[tsla_df['Volume'].idxmax(), 'Date']
max_data = tsla_df.loc[tsla_df['Volume'].idxmax()]
price_change = '올랐습니다.' if max_data['Close'] > max_data['Open'] else '내렸습니다.'
print("거래량이 높았던 날은", max_date, "이며 주가는", price_change)

# 4) 3,4,5월 중에서 평균적으로 종가(Close)가 가장 높은 달은?
tsla.groupby(tsla.Date.dt.month)['Close'].mean().sort_values().index[-1]

# 5) 종가 및 거래량 데이터를 활용하여 시각화(선그래프) 출력
tsla
plt.plot(tsla.Close)
plt.show()


# 6) 주가가 오른 날이 많았을까? 내린 날이 많았을까?
tsla_df['Price Change'] =tsla_df['Close'] - tsla_df['Open']
up_day = tsla_df[tsla_df['Price Change'] > 0].shape[0]
down_day = tsla_df[tsla_df['Price Change'] < 0].shape[0]

reult = '주가가 오른날이 많았습니다.' if up_day > down_day else '주가가 내린날이 많았습니다.'

print('오른 일수는',up_day,'일이고 내린 일수는 ', down_day,'일입니다. 결론은 ',reult)
# Out:
# 편차가 큰 날짜는: 2024-04-25
# 거래량이 높았던 날은 2024-04-29 이며 주가는 올랐습니다.
# 2024-04-29 194.050003 Date
# 2024-03-04    188.139999
# 2024-03-05    180.740005
# 2024-03-06    176.539993
# 2024-03-07    178.649994
# 2024-03-08    175.339996
#                  ...
# 2024-05-24    179.240005
# 2024-05-28    176.750000
# 2024-05-29    176.190002
# 2024-05-30    178.789993
# 2024-05-31    178.080002
# Name: Close, Length: 63, dtype: float64
# 오른 일수는 29 일이고 내린 일수는  34 일입니다. 결론은  주가가 내린날이 많았습니다.

# %%
# 2. 인구
df = pd.read_csv('data2/gapminder.tsv', sep='\t')
# 1) 대륙별로 기대수명이 평균적으로 가장 높은 대륙은?
df.groupby('continent')['lifeExp'].mean().index[-1]
# 2) 대륙 별 국가의 개수를 출력하시오
df.groupby('continent')['country'].agg('count')/len(df.year.unique())
# 3) 기대수명이 가장 높은 국가는?
df[df.lifeExp == df.lifeExp.max()].country
# 4) 1952~2007년까지 gdp가 가장 크게 증가한 나라는? 증가율은?
df2 = df[(df['year']==1952)].reset_index(drop=True)
df2007 = df[df.year == 2007]['gdpPercap'].reset_index(drop=True)
df1952 = df[df.year == 1952]['gdpPercap'].reset_index(drop=True)
df2['diff'] = df2007 - df1952
res_country = df2[df2['diff'] == df2['diff'].max()].country.values[0] # 싱가포르
str((df2[df2.country == res_country]['diff']/  df[df['country'] == res_country][df.year == 1952].gdpPercap.values[0] * 100).values[0])+'%'
# diff값 / 1952년도 gdp값 * 100(백분율 계산)
# 5) 1952~2007년까지 pop가 가장 크게 증가한 나라는? 증가율은?
df3 = df[(df['year']==1952)].reset_index(drop=True)
df3['diffPop'] = df[df['year'] == 2007]['pop'].reset_index(drop=True) - df[df['year'] == 1952]['pop'].reset_index(drop=True)
res_df = df3[df3.diffPop == df3.diffPop.max()] # 최대 차이를 보이는 국가는 중국
str((res_df.diffPop/res_df['pop'] * 100).values[0])+'%'
# Out:
# ('Japan',
#  82.603,
#  'Equatorial Guinea',
#  3135.541662442322,
#  'Kuwait',
#  1465.974375)

# %%
# 1. 테슬라
tsla = pd.read_csv('TSLA.csv', parse_dates=['Date'])
# 1) High / Low /Close / Volume 열에 대해 최대/최소/평균/중위수 출력
tsla.describe()
# 2) Open열과 Close 열 값의 차이가 가장 큰 날짜는 언제인가?
tsla['diff'] = tsla.Open - tsla.Close
tsla[tsla['diff'].abs() == tsla['diff'].abs().max()].Date
# 3) Volume(거래량)이 가장 높았던 날에는 주가가 올랐을까 내렸을까?
tsla[tsla.Volume == tsla.Volume.max()]['diff'] # diff값이 음수면 오른 것임
# 4) 3,4,5월 중에서 평균적으로 종가(Close)가 가장 높은 달은?
tsla.groupby(tsla.Date.dt.month)['Close'].mean().sort_values().index[-1]
# 5) 종가 및 거래량 데이터를 활용하여 시각화(선그래프) 출력
import matplotlib.pyplot as plt
tsla
plt.plot(tsla.Close)
plt.show()
# 6) 주가가 오른 날이 많았을까? 내린 날이 많았을까?
print(tsla.shape[0]) # 주식 열린 일수
tsla[tsla['diff']>0]['diff'].count() # 주식이 내린 횟수(시작-종료이므로 양수이면 내려간 것)
(tsla.shape[0] / 2) < (tsla[tsla['diff']>0]['diff'].count()) # diff가 더 크므로 내린날이 더 많았음
